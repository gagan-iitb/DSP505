# %% [markdown]
# <a href="https://colab.research.google.com/github/gagan-iitb/DSP505/blob/main/Notebooks/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Seed for reproducibility
np.random.seed(42)

# Creating a dummy dataset
data = {
    'Age': np.random.randint(18, 65, 100),
    'Gender': np.random.choice(['Male', 'Female'], 100),
    'Income': np.random.randint(20000, 100000, 100),
    'Education': np.random.choice(['High School', 'Bachelor\'s', 'Master\'s', 'PhD'], 100),
    'City': np.random.choice(['City A', 'City B', 'City C'], 100),
    'Purchased': np.random.choice(['Yes', 'No'], 100)
}

df = pd.DataFrame(data)
df.head()
# Out:
#    Age  Gender  Income    Education    City Purchased
# 0   56  Female   41976     Master's  City B        No
# 1   46  Female   64262  High School  City C       Yes
# 2   32    Male   43776  High School  City B       Yes
# 3   60    Male   50080   Bachelor's  City B        No
# 4   25    Male   86842          PhD  City C       Yes

# %% [markdown]
# Plot a bar plot and a pie chart for the Gender and Purchased columns.
#
# Which plot makes it easier to compare categories? When would you prefer a bar plot over a pie chart, or vice versa?

# %% [markdown]
# Plot a scatter plot for Age vs. Income, colored by the Purchased column.
# Create a heatmap of the correlation matrix for Age, Income, and other numerical features.
# How do these plots help you understand the relationship between variables? Which plot gives you more insight into the data

# %%
import seaborn as sns

# Load the iris dataset directly as a pandas DataFrame
iris_df = sns.load_dataset('iris')
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Step 1: Plot the relationship between PetalLengthCm and PetalWidthCm using a 2D scatter plot.
#
# Step 2: Now, plot a 3D scatter plot by adding SepalLengthCm as the third dimension.
#
# Which plot (2D or 3D) is more effective in helping you distinguish between the different species? Explain why.
